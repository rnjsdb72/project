# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import os

# %%
data_dnn = pd.read_csv(os.path.abspath("../input")+'/5. dnn_submission_8.15961.csv')

# %%
# 8.12043
data10 = pd.read_csv(os.path.abspath("../input")+'/124_average.csv')

# %%
data_yj = pd.read_csv(os.path.abspath("../input")+'/results_ensemble_ela_lgbm.csv')

# %% [markdown]
# ## 앙상블

# %%
# 8.07796
pred = data_dnn.age*0.4+data10.age*0.4+data_yj.age*0.2
pd.DataFrame({'custid': data_dnn.custid, 'age':pred}).to_csv('dnn_1_yj.csv', index=False)
