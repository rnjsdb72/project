# %%
import pandas as pd
import os

# %%
data1 = pd.read_csv(os.path.abspath("../input")+'/submission_1등.csv')

# %%
data2 = pd.read_csv(os.path.abspath("../input")+'/submission_2등.csv')

# %%
data4 = pd.read_csv(os.path.abspath("../input")+'/averaging_rid_lgbm_cat.csv')

# %%
data4['age'] = (data1.age + data2.age + data4.age)/3

# %%
data4.set_index('custid').to_csv('124_average.csv')
