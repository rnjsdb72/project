# %%
import pandas as pd
import numpy as np
import arrow
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
plt.rc('font', family='malgun gothic')
plt.rc('axes', unicode_minus=False)

# %%
demo = pd.read_csv('Demo.csv', encoding = 'cp949')
tran = pd.read_csv('구매내역정보.csv', encoding = 'cp949', engine = 'python')

# %%
mg = pd.merge(demo, tran, on = 'ID')

# %%
mg.head()
# Out:
#           ID  성별  연령    거주지역 상품대분류명      상품중분류명     구매지역      구매일자  구매시간  \
# 0  478207946   1  84  서울 성동구   가전제품     컴퓨터주변기기  서울 동대문구  20141219    13
# 1  478207946   1  84  서울 성동구   가전제품       TV/AV  서울 동대문구  20141031    14
# 2  478207946   1  84  서울 성동구   가전제품        주방가전    서울 중구  20140815    15
# 3  478207946   1  84  서울 성동구   의류잡화  여성용의류-이너웨어  서울 동대문구  20140322    17
# 4  479806984   1  84  서울 서초구   생활잡화         화장품    서울 중구  20140704    12
#
#    구매수량    구매금액  취소여부
# 0     1   59000     0
# 1     1  106000     0
# 2     1   37000     0
# 3     1  118000     0
# 4     1   22000     0

# %%
mg['구매지역_광역']=[mg.구매지역[i].split()[0] for i in range(len(mg.구매지역))]

# %%
def season(x):
    if 5>=int(str(x)[4:6])>=3:
        return('봄')
    elif 8>=int(str(x)[4:6])>=6:
        return('여름')
    elif 11>=int(str(x)[4:6])>=9:
        return('가을')
    else:
        return('겨울')
    
mg['계절'] = mg.구매일자.apply(season)

# %%
shit = mg.groupby(['계절','상품대분류명']).구매수량.sum().reset_index()

# %%
shit.query('상품대분류명=="가구"')
# Out:
#     계절 상품대분류명  구매수량
# 0   가을     가구   152
# 7   겨울     가구   189
# 14   봄     가구   141
# 21  여름     가구   169

# %%
sns.relplot(x='상품대분류명', y='구매수량', hue = '계절', data = shit, hue_order=['봄','여름','가을','겨울'], kind = 'line')
plt.show()

# %%
sns.catplot(x='상품대분류명', y='구매수량', data = shit, kind = 'box')
plt.show()

# %%
std1 = mg.groupby(['상품대분류명','계절'])['구매수량'].sum().reset_index()
std2 = pd.DataFrame()
std2['상품대분류명'] = shit.상품대분류명
std2['계절별표준편차'] = [np.std(std1.query('상품대분류명 == @i')['구매수량']) for i in shit.상품대분류명]
std2[:7]
# Out:
#   상품대분류명      계절별표준편차
# 0     가구    18.143525
# 1   가전제품  1176.549271
# 2    레포츠   642.842273
# 3     명품    12.328828
# 4   생활잡화   723.445402
# 5     식품  1439.838967
# 6   의류잡화   568.953590

# %%
np.std(std1.query('상품대분류명 == "가구"')['구매수량'])
# Out:
# 18.14352501582865

# %%
mg = mg.drop(mg.query('구매금액 == 0').reset_index()['index'],axis=0) # 구매금액이 0원인 것 지움.

# %%
mg['평균금액'] = (mg['구매금액']/mg['구매수량']).astype(int)

# %%
mg = mg.drop(mg.query('평균금액 < 100').reset_index()['index'],axis = 0) # 평균금액 100원 미만 다 지움
mg = mg.drop(mg.query('평균금액 <= 200').reset_index()['index'], axis = 0) 
mg = mg.drop(mg[mg.평균금액.apply(lambda x: str(x)[-1]) != "0"].reset_index()['index'], axis = 0)
mg = mg.reset_index().drop('index', axis=1)
mg.head()
# Out:
#           ID  성별  연령    거주지역 상품대분류명      상품중분류명     구매지역      구매일자  구매시간  \
# 0  478207946   1  84  서울 성동구   가전제품     컴퓨터주변기기  서울 동대문구  20141219    13
# 1  478207946   1  84  서울 성동구   가전제품       TV/AV  서울 동대문구  20141031    14
# 2  478207946   1  84  서울 성동구   가전제품        주방가전    서울 중구  20140815    15
# 3  478207946   1  84  서울 성동구   의류잡화  여성용의류-이너웨어  서울 동대문구  20140322    17
# 4  479806984   1  84  서울 서초구   생활잡화         화장품    서울 중구  20140704    12
#
#    구매수량    구매금액  취소여부 구매지역_광역  계절    평균금액
# 0     1   59000     0      서울  겨울   59000
# 1     1  106000     0      서울  가을  106000
# 2     1   37000     0      서울  여름   37000
# 3     1  118000     0      서울   봄  118000
# 4     1   22000     0      서울  여름   22000

# %%
mg[mg.평균금액.apply(lambda x: str(x)[-1]) != "0"]
# Out:
# Empty DataFrame
# Columns: [ID, 성별, 연령, 거주지역, 상품대분류명, 상품중분류명, 구매지역, 구매일자, 구매시간, 구매수량, 구매금액, 취소여부, 구매지역_광역, 계절, 평균금액]
# Index: []

# %%
mg.shape
# Out:
# (100076, 15)

# %%
mg.to_csv('merging_data.csv')
mg
# Out:
#                ID  성별  연령     거주지역 상품대분류명      상품중분류명     구매지역      구매일자  \
# 0       478207946   1  84   서울 성동구   가전제품     컴퓨터주변기기  서울 동대문구  20141219
# 1       478207946   1  84   서울 성동구   가전제품       TV/AV  서울 동대문구  20141031
# 2       478207946   1  84   서울 성동구   가전제품        주방가전    서울 중구  20140815
# 3       478207946   1  84   서울 성동구   의류잡화  여성용의류-이너웨어  서울 동대문구  20140322
# 4       479806984   1  84   서울 서초구   생활잡화         화장품    서울 중구  20140704
# 5       479806984   1  84   서울 서초구   생활잡화         화장품    서울 중구  20140704
# 6       479806984   1  84   서울 서초구   생활잡화         화장품    서울 중구  20140704
# 7       479806984   1  84   서울 서초구   가전제품        생활가전   서울 송파구  20141218
# 8       479806984   1  84   서울 서초구   가전제품        생활가전    서울 중구  20140607
# 9        94790213   1  84   부산 사상구   생활잡화        생활용품  부산 부산진구  20140714
# 10       94790213   1  84   부산 사상구   가전제품        생활가전  부산 부산진구  20141212
# 11       94790213   1  84   부산 사상구   가전제품       TV/AV  부산 부산진구  20140529
# 12       94790213   1  84   부산 사상구     식품        가공식품  부산 부산진구  20140623
# 13       94790213   1  84   부산 사상구   의류잡화        패션잡화  부산 부산진구  20140207
# 14      656026338   1  84  서울 영등포구     식품        가공식품  서울 영등포구  20140926
# 15      656026338   1  84  서울 영등포구     식품        가공식품  서울 영등포구  20140505
# 16      656026338   1  84  서울 영등포구     식품        가공식품  서울 영등포구  20140127
# 17      433076833   1  83   경기 고양시   가전제품        생활가전   경기 고양시  20141004
# 18      433076833   1  83   경기 고양시     식품        가공식품    서울 중구  20141025
# 19      433076833   1  83   경기 고양시     식품          음료    서울 중구  20140423
# 20      433076833   1  83   경기 고양시     식품          음료    서울 중구  20140423
# 100074  821581510   2  64   경기 안양시     식품        가공식품   경기 광명시  20141221
# 100075  821581510   2  64   경기 안양시   의류잡화   여성용의류-SPA   경기 광명시  20141221
#
#         구매시간  구매수량     구매금액  취소여부 구매지역_광역  계절     평균금액
# 0         13     1    59000     0      서울  겨울    59000
# 1         14     1   106000     0      서울  가을   106000
# 2         15     1    37000     0      서울  여름    37000
# 3         17     1   118000     0      서울   봄   118000
# 4         12     1    22000     0      서울  여름    22000
# 5         12     1    26000     0      서울  여름    26000
# 6         12     1    53000     0      서울  여름    53000
# 7         13     1   120000     0      서울  겨울   120000
# 8         14     1    97000     0      서울  여름    97000
# 9         14     1    12000     0      부산  여름    12000
# 10        16     1    35000     0      부산  겨울    35000
# 11        17     1    23000     0      부산   봄    23000
# 12        17     2    10000     0      부산  여름     5000
# 13        17     1    22000     0      부산  겨울    22000
# 14        14     1    13000     0      서울  가을    13000
# 15        16     1     8000     0      서울   봄     8000
# 16        17     1     8000     0      서울  겨울     8000
# 17        10     1    11000     0      경기  가을    11000
# 18        11     1     3000     0      서울  가을     3000
# 19        11     1     1000     0      서울   봄     1000
# 20        11     1     3000     0      서울   봄     3000
# 21        11     2     2000     0      서울   봄     1000
# 22        11     1     4000     0      서울   봄     4000
# 23        11     1     1000     0      서울  여름     1000
# 24        11     1     3000     0      서울  여름     3000
# 25        11     1     1000     0      서울  가을     1000
# 26        11     1     2000     0      서울  가을     2000
# 27        11     2     4000     0      서울  가을     2000
# 28        11     1     1000     0      서울  가을     1000
# 29        12     1    10000     0      서울   봄    10000
# ...      ...   ...      ...   ...     ...  ..      ...
# 100046    12     1   311000     0      경기  가을   311000
# 100047    15     1   178000     0      경기  겨울   178000
# 100048    11     1   542000     0      부산  겨울   542000
# 100049    11     1   141000     0      부산  겨울   141000
# 100050    12     1   249000     0      부산  겨울   249000
# 100051    13     1     2000     0      부산  겨울     2000
# 100052    13     1    40000     0      부산  겨울    40000
# 100053    16     1    12000     0      부산  겨울    12000
# 100054    16     1   524000     0      부산  겨울   524000
# 100055    12     1    44000     0      경기  가을    44000
# 100056    14     1    60000     0      경기   봄    60000
# 100057    14     1   879000     0      서울  겨울   879000
# 100058    15     1   157000     0      경기  겨울   157000
# 100059    16     1     9000     0      경기  겨울     9000
# 100060    16     1    11000     0      경기  겨울    11000
# 100061    16     1    96000     0      경기  겨울    96000
# 100062    16     1    39000     0      부산  겨울    39000
# 100063    16     1   123000     0      부산  겨울   123000
# 100064    19     1   684000     0      부산  겨울   684000
# 100065    18     1    21000     0      경기  겨울    21000
# 100066    19     1    11000     0      경기  겨울    11000
# 100067    19     1     9000     0      경기  겨울     9000
# 100068    19     1     9000     0      경기  겨울     9000
# 100069    19     1     1000     0      경기  겨울     1000
# 100070    19     1     9000     0      경기  겨울     9000
# 100071    19     1    60000     0      경기  겨울    60000
# 100072    19     3    93000     0      경기  겨울    31000
# 100073    20     1  1057000     0      경기  겨울  1057000
# 100074    12     1     5000     0      경기  겨울     5000
# 100075    12     1    62000     0      경기  겨울    62000
#
# [100076 rows x 15 columns]
